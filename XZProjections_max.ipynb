# %%
# %pylab inline
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib.cm as cm
import matplotlib.figure as fig
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
import numpy.ma as ma
from netCDF4 import Dataset
from scipy.ndimage import label, generate_binary_structure
from collections import Counter
import xarray as xr 
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Grab defined variables from 2kbub.nc

ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000050.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']
#u = fl.variables['uinterp'][:]
#v = fl.variables['vinterp'][:]                   #read in velocity vecotrs interpolated between scalar points
#w = fl.variables['winterp'][:]
#zvort = fl.variables['zvort'][:]
#uh = fl.variables['uh']
#th = fl.variables['thpert'][:]
#theta = fl.variables['th'][:]
#dbz = fl.variables['dbz'][:]
#prs = fl.variables['prs'][:]                
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]
#print(np.shape(x))

#make qtotal
qtot = (qr+qg+qs+qc+qi+qhl)*1000.
#print(np.max(uh[6]))
qtotymax1 = np.amax(qtot, axis=2)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000080.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']
#u = fl.variables['uinterp'][:]
#v = fl.variables['vinterp'][:]                   #read in velocity vecotrs interpolated between scalar points
#w = fl.variables['winterp'][:]
#zvort = fl.variables['zvort'][:]
#uh = fl.variables['uh']
#th = fl.variables['thpert'][:]
#theta = fl.variables['th'][:]
#dbz = fl.variables['dbz'][:]
#prs = fl.variables['prs'][:]                
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot = (qr+qg+qs+qc+qi+qhl)*1000.
#print(np.max(uh[6]))
qtotymax2 = np.amax(qtot, axis=2)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000110.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']
#u = fl.variables['uinterp'][:]
#v = fl.variables['vinterp'][:]                   #read in velocity vecotrs interpolated between scalar points
#w = fl.variables['winterp'][:]
#zvort = fl.variables['zvort'][:]
#uh = fl.variables['uh']
#th = fl.variables['thpert'][:]
#theta = fl.variables['th'][:]
#dbz = fl.variables['dbz'][:]
#prs = fl.variables['prs'][:]                
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax3 = np.amax(qtot, axis=2)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000140.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']  
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax4 = np.amax(qtot, axis=2)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000170.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z'] 
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax5 = np.amax(qtot, axis=2)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000200.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']           
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax6 = np.amax(qtot, axis=2)
#qtotymax = np.amax(prspert, axis=2)

# %%
qtotymax = np.concatenate((qtotymax1,qtotymax2,qtotymax3,qtotymax4,qtotymax5,qtotymax6),axis=0)

# %%
files = np.array([1,2,3,4,5,6])
print(np.shape(qtotymax))

print(np.shape(qtot))
# Out:
# (6, 200, 880)
# (1, 200, 880, 880)

# %%
for i in range(len(files)):
    plt.figure(figsize=(20,6))
    plt.xlim(175,775)
    plt.ylim(0,180)
    #plt.contourf(qtotymax[i,:,:],cmap=cm.gist_ncar,levels=np.linspace(-20, 120, 500))
    plt.contourf(qtotymax[i,:,:],cmap=cm.gist_ncar,levels=np.linspace(0.01, 20, 500))
    plt.colorbar()
    #savestr = 'qtot_'+ str(i) +'.png'
    #plt.savefig(savestr,dpi = 300)
