# %%
# %pylab inline
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib.cm as cm
import matplotlib.figure as fig
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
import numpy.ma as ma
from netCDF4 import Dataset
from scipy.ndimage import label, generate_binary_structure
from collections import Counter
import xarray as xr 
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['qr']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# Grab defined variables from 2kbub.nc

ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000050.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']
#u = fl.variables['uinterp'][:]
#v = fl.variables['vinterp'][:]                   #read in velocity vecotrs interpolated between scalar points
#w = fl.variables['winterp'][:]
#zvort = fl.variables['zvort'][:]
#uh = fl.variables['uh']
#th = fl.variables['thpert'][:]
#theta = fl.variables['th'][:]
#dbz = fl.variables['dbz'][:]
#prs = fl.variables['prs'][:]                
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]
#print(np.shape(x))

#make qtotal
qtot1 = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax1 = np.amax(qtot1, axis=1)
#qtotymax = np.amax(prspert, axis=2)
print(np.shape(qtotymax1))
# Out:
# (1, 880, 880)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000080.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']
#u = fl.variables['uinterp'][:]
#v = fl.variables['vinterp'][:]                   #read in velocity vecotrs interpolated between scalar points
#w = fl.variables['winterp'][:]
#zvort = fl.variables['zvort'][:]
#uh = fl.variables['uh']
#th = fl.variables['thpert'][:]
#theta = fl.variables['th'][:]
#dbz = fl.variables['dbz'][:]
#prs = fl.variables['prs'][:]                
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot2 = (qr+qg+qs+qc+qi+qhl)*1000.
#print(np.max(uh[6]))
qtotymax2 = np.amax(qtot2, axis=1)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000110.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']
#u = fl.variables['uinterp'][:]
#v = fl.variables['vinterp'][:]                   #read in velocity vecotrs interpolated between scalar points
#w = fl.variables['winterp'][:]
#zvort = fl.variables['zvort'][:]
#uh = fl.variables['uh']
#th = fl.variables['thpert'][:]
#theta = fl.variables['th'][:]
#dbz = fl.variables['dbz'][:]
#prs = fl.variables['prs'][:]                
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot3 = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax3 = np.amax(qtot3, axis=1)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000140.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']  
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot4 = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax4 = np.amax(qtot4, axis=1)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000170.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z'] 
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot5 = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax5 = np.amax(qtot5, axis=1)
#qtotymax = np.amax(prspert, axis=2)

# %%
ncfile = '/data/slasher/a/engelse2/Entrain/Carp100_Full500_nssl_000200.nc' 
fl = Dataset(ncfile,mode='r')

t = fl.variables['time']
x = fl.variables['xh']
y = fl.variables['yh']
z = fl.variables['z']           
qv = fl.variables['qv'][:]
qr = fl.variables['qr'][:]
qg = fl.variables['qg'][:]
qs = fl.variables['qs'][:]
qc = fl.variables['qc'][:]
qi = fl.variables['qi'][:]
qhl = fl.variables['qhl'][:]
prspert = fl.variables['prspert'][:]

#make qtotal
qtot6 = (qr+qg+qs+qc+qi+qhl)*1000.
qtotymax6 = np.amax(qtot6, axis=1)
#qtotymax = np.amax(prspert, axis=2)
print(np.shape(qtotymax6))
# Out:
# (1, 880, 880)

# %%
print(np.shape(qtotymax1))
# Out:
# ()

# %%
qtotymax = np.concatenate((qtotymax1,qtotymax2,qtotymax3,qtotymax4,qtotymax5,qtotymax6),axis=0)
qtottotal = np.concatenate((qtot1,qtot2,qtot3,qtot4,qtot5,qtot6),axis=0)


print(np.shape(qtotymax))
print(np.shape(qtottotal))
# Out:
# (6, 880, 880)
# (6, 200, 880, 880)

# %%
newt=np.arange(0,6,1)
qtotlocz = np.array((np.zeros(6),np.zeros(6)))
for i in range(len(newt)):
    qtotlocz[:,i] = np.unravel_index(qtotymax[i,:,:].argmax(),qtotymax[i,:,:].shape)
print((qtotlocz))


# # Tracking uh of right mover
# newt=np.arange(0,9,1)
# newww = np.array((np.zeros(9),np.zeros(9)))
# for i in range(len(newt)):
#     newww[:,i] = np.unravel_index(uh[i,:,:].argmax(),uh[i,:,:].shape)
    
# print(newww)
# Out:
# [[ 334.  345.  354.  363.  371.  394.]
#  [ 294.  314.  338.  326.  360.  377.]]

# %%
qtotlocy = qtotloc[0,:]
print(qtotlocy)
# Out:
# [ 334.  345.  354.  363.  371.  394.]

# %%
for i in range(len(newt)):
    plt.figure(figsize=(20,6))
    plt.xlim(175,775)
    plt.ylim(0,180)
    #plt.contourf(qtotymax[i,:,:],cmap=cm.gist_ncar,levels=np.linspace(-20, 120, 500))
    plt.contourf(qtottotal[i,:,qtotlocy[i],:],cmap=cm.gist_ncar,levels=np.linspace(0.01, 20, 500))
    plt.colorbar()
    #savestr = 'qtot_'+ str(i) +'.png'
    #plt.savefig(savestr,dpi = 300)
# Out:
# /net/san-a1-ib/data/keeling/a/engelse2/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
